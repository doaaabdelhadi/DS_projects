# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %matplotlib inline

# %%
edu=pd.read_csv('Education Index.csv',engine='python')

# %%
edu.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                       Education Index
# HDI Rank (2017) Country      1990.000 NaN 1991.000 NaN 1992.000 NaN 1993.000 NaN 1994.000 NaN 1995.000 NaN 1996.000 NaN 1997.000 NaN 1998.000 NaN 1999.000 NaN 2000.000 NaN 2001.000 NaN 2002.000 NaN 2003.000 NaN 2004.000 NaN 2005.000 NaN 2006.000 NaN 2007.000 NaN 2008.000 NaN 2009.000 NaN 2010.000 NaN 2011.000 NaN 2012.000 NaN 2013.000 NaN 2014.000 NaN 2015.000 NaN 2016.000 NaN 2017.000              NaN
# ...

# %%
edu.reset_index(inplace=True)
# edu.loc[edu['Country']=='Egypt']

# %%
edu.head()
# Out:
#            level_0       level_1   level_2  level_3   level_4  level_5  \
# 0  HDI Rank (2017)       Country  1990.000      NaN  1991.000      NaN
# 1              168   Afghanistan     0.122      NaN     0.133      NaN
# 2               68       Albania     0.584      NaN     0.589      NaN
# 3               85       Algeria     0.385      NaN     0.395      NaN
# 4               35       Andorra       NaN      NaN       NaN      NaN
#
#     level_6  level_7   level_8  level_9       ...         level_48  level_49  \
# 0  1992.000      NaN  1993.000      NaN       ...         2013.000       NaN
# 1     0.145      NaN     0.156      NaN       ...            0.398       NaN
# 2     0.558      NaN     0.543      NaN       ...            0.732       NaN
# 3     0.405      NaN     0.414      NaN       ...            0.660       NaN
# 4       NaN      NaN       NaN      NaN       ...            0.715       NaN
#
#    level_50  level_51  level_52  level_53  level_54  level_55  level_56  \
# ...

# %%
num=range(3,58,2)
i=list(map(lambda x:x,num ))
# num


edu.drop(edu.columns[i], axis = 1,inplace=True)

# %%
year=range(1990,2018)
col=['HDI Rank (2017)','Country']
col.extend(list(map(lambda x:x,year)))
edu.columns=col

# %%
edu.head()
# Out:
#    HDI Rank (2017)       Country      1990      1991      1992      1993  \
# 0  HDI Rank (2017)       Country  1990.000  1991.000  1992.000  1993.000
# 1              168   Afghanistan     0.122     0.133     0.145     0.156
# 2               68       Albania     0.584     0.589     0.558     0.543
# 3               85       Algeria     0.385     0.395     0.405     0.414
# 4               35       Andorra       NaN       NaN       NaN       NaN
#
#        1994      1995      1996      1997    ...         2008      2009  \
# 0  1994.000  1995.000  1996.000  1997.000    ...     2008.000  2009.000
# 1     0.168     0.179     0.190     0.202    ...        0.347     0.359
# 2     0.542     0.551     0.558     0.571    ...        0.646     0.652
# 3     0.424     0.431     0.443     0.458    ...        0.588     0.608
# 4       NaN       NaN       NaN       NaN    ...        0.661     0.661
#
#        2010      2011      2012      2013      2014      2015      2016  \
# ...

# %%
edu.drop(0,inplace=True)

# %%
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189 entries, 1 to 189
# Data columns (total 30 columns):
# HDI Rank (2017)    189 non-null object
# Country            189 non-null object
# 1990               144 non-null float64
# 1991               144 non-null float64
# 1992               144 non-null float64
# 1993               144 non-null float64
# 1994               144 non-null float64
# 1995               148 non-null float64
# 1996               148 non-null float64
# 1997               148 non-null float64
# 1998               148 non-null float64
# 1999               151 non-null float64
# 2000               173 non-null float64
# 2001               173 non-null float64
# 2002               174 non-null float64
# 2003               176 non-null float64
# 2004               179 non-null float64
# 2005               186 non-null float64
# 2006               186 non-null float64
# 2007               186 non-null float64
# 2008               186 non-null float64
# ...

# %%
edu['Country']=edu['Country'].str.replace(' ','')
countries= edu['Country'].unique().tolist()

# edu.loc[edu['Country']=='egypt']
countries[5:15]
# Out:
# ['AntiguaandBarbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados']

# %%
Egypt=edu.loc[edu['Country']=='Egypt']

# %%
Egypt1=Egypt.T

# %%
Egypt1.columns=['values']

# %%
Egypt1.drop(['HDI Rank (2017)','Country'],inplace=True)

# %%
Egypt1.plot()

# %%
hdi=pd.read_csv('Human development index (HDI).csv',engine='python')

# %%
# rest_index
hdi.reset_index(inplace=True)
hdi.head()
# Out:
#    index          level_0       level_1   level_2   level_3   level_4  \
# 0      0  HDI Rank (2017)       Country  1990.000  1991.000  1992.000
# 1      1              168   Afghanistan       NaN       NaN       NaN
# 2      2               68       Albania     0.645     0.626     0.610
# 3      3               85       Algeria     0.577     0.581     0.587
# 4      4               35       Andorra       NaN       NaN       NaN
#
#     level_5   level_6   level_7   level_8              ...                \
# 0  1993.000  1994.000  1995.000  1996.000              ...
# 1       NaN       NaN       NaN       NaN              ...
# 2     0.613     0.619     0.632     0.641              ...
# 3     0.591     0.595     0.600     0.608              ...
# 4       NaN       NaN       NaN       NaN              ...
#
#    level_20  level_21  level_22  level_23  level_24  level_25  level_26  \
# 0  2008.000  2009.000  2010.000  2011.000  2012.000  2013.000  2014.000
# ...

# %%
hdi.drop(['index'],axis='columns',inplace=True)

# %%
hdi.columns=col

# %%
hdi.drop(0,inplace=True)
hdi.head()
# Out:
#   HDI Rank (2017)       Country   1990   1991   1992   1993   1994   1995  \
# 1             168   Afghanistan    NaN    NaN    NaN    NaN    NaN    NaN
# 2              68       Albania  0.645  0.626  0.610  0.613  0.619  0.632
# 3              85       Algeria  0.577  0.581  0.587  0.591  0.595  0.600
# 4              35       Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 5             147        Angola    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1996   1997  ...     2008   2009   2010   2011   2012   2013   2014  \
# 1    NaN    NaN  ...    0.437  0.453  0.463  0.471  0.482  0.487  0.491
# 2  0.641  0.641  ...    0.724  0.729  0.741  0.752  0.767  0.771  0.773
# 3  0.608  0.617  ...    0.709  0.719  0.729  0.736  0.740  0.745  0.747
# 4    NaN    NaN  ...    0.831  0.830  0.828  0.827  0.849  0.850  0.853
# 5    NaN    NaN  ...    0.502  0.522  0.520  0.535  0.543  0.554  0.564
#
#     2015   2016   2017
# 1  0.493  0.494  0.498
# 2  0.776  0.782  0.785
# ...

# %%
hdi['Country']=hdi['Country'].str.replace(' ','')

egypt_hdi=hdi.loc[hdi['Country']=='Egypt']
# egypt_hdi.isnull().sum()

# %%
egypt_hdi1= egypt_hdi.T

# %%
egypt_hdi1.columns=['values']

# %%
egypt_hdi1.drop(['HDI Rank (2017)','Country'],inplace=True)

# %%
# sns.relplot(x=egypt_hdi1,y=Egypt1)
# Egypt1.plot()

# %%
E_hdi= egypt_hdi1.T

# %%
E_edu=Egypt1.T

# %%
# E_edu

# %%
df=E_hdi.merge(E_edu,how='outer')

# %%
df=df.T

# %%
df.columns=['HDI','EDU']

# %%
ax=sns.scatterplot(data=df)
ax.set_title('HDI Vs Education in Egypt(1995-2017)')
ax.set_xlabel('Year')
ax.set_ylabel('values')
# Out:
# Text(0,0.5,'values')

# %%
# edu.head()

# %%
# hdi.head()

# %%
# df2=hdi.merge(edu,on='Country',how='inner')

# %%
# df2
